# %%
import pandas as pd

# %%
con_belief = pd.read_csv('data/conspiracy_belief_score.csv')

con_belief
# Out:
#       conspiracy_belief_score              education             childhood  \
# 0                    4.333333  Less than high school              Suburban
# 1                    2.466667        Graduate degree              Suburban
# 2                    3.666667      University degree  Rural (country side)
# 3                    3.933333            High school              Suburban
# 4                    1.000000      University degree  Rural (country side)
# ...                       ...                    ...                   ...
# 2296                 3.066667      University degree    Urban (town, city)
# 2297                 1.333333        Graduate degree              Suburban
# 2298                 3.800000            High school    Urban (town, city)
# 2299                 1.666667            High school              Suburban
# 2300                 3.400000  Less than high school    Urban (town, city)
#
#       gender   hand  family_size  age  test_time
# ...

# %%
con_belief.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2301 entries, 0 to 2300
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   conspiracy_belief_score  2301 non-null   float64
#  1   education                2301 non-null   object
#  2   childhood                2301 non-null   object
#  3   gender                   2301 non-null   object
#  4   hand                     2301 non-null   object
#  5   family_size              2301 non-null   int64
#  6   age                      2301 non-null   int64
#  7   test_time                2301 non-null   int64
# dtypes: float64(1), int64(3), object(4)
# memory usage: 143.9+ KB

# %%
con_belief.describe(include='all')
# Out:
#         conspiracy_belief_score    education childhood gender   hand  \
# count               2301.000000         2301      2301   2301   2301
# unique                      NaN            4         3      3      2
# top                         NaN  High school  Suburban   Male  Right
# freq                        NaN         1013      1056   1143   2052
# mean                   2.887266          NaN       NaN    NaN    NaN
# std                    1.033407          NaN       NaN    NaN    NaN
# min                    0.866667          NaN       NaN    NaN    NaN
# 25%                    2.066667          NaN       NaN    NaN    NaN
# 50%                    2.866667          NaN       NaN    NaN    NaN
# 75%                    3.666667          NaN       NaN    NaN    NaN
# max                    5.000000          NaN       NaN    NaN    NaN
#
#         family_size          age    test_time
# count   2301.000000  2301.000000  2301.000000
# ...
