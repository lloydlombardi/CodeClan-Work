# %%
import pandas as pd
from janitor import clean_names

# %%
regional_tourism = pd.read_csv('data/regional_domestic_tourism.csv').clean_names()

accomodation_occupancy = pd.read_csv('data/scottish_accomodation_occupancy.csv').clean_names()

activities = pd.read_csv('data/tourism_day_visits_activities.csv').clean_names()

demographics = pd.read_csv('data/tourism_day_visits_demographics.csv').clean_names()

location = pd.read_csv('data/tourism_day_visits_location.csv').clean_names()

transport = pd.read_csv('data/tourism_day_visits_transport.csv').clean_names()

# %%
regional_tourism.isna().sum()
# Out:
# featurecode                      0
# datecode                         0
# measurement                      0
# units                            0
# value                            0
# region_of_residence              0
# breakdown_of_domestic_tourism    0
# dtype: int64

# %%
accomodation_occupancy.isna().sum()
# Out:
# featurecode                         0
# datecode                            0
# measurement                         0
# units                               0
# value                               0
# accommodation_type_and_occupancy    0
# weekday_weekend                     0
# size_of_accommodation               0
# location                            0
# dtype: int64

# %%
activities.isna().sum()
# Out:
# featurecode                      0
# datecode                         0
# measurement                      0
# units                            0
# value                            0
# tourism_activity                 0
# breakdown_of_domestic_tourism    0
# dtype: int64

# %%
demographics.isna().sum()
# Out:
# featurecode                      0
# datecode                         0
# measurement                      0
# units                            0
# value                            0
# breakdown_of_domestic_tourism    0
# age                              0
# marital_status                   0
# gender                           0
# employment_status                0
# children                         0
# access_to_car                    0
# social_grade                     0
# dtype: int64

# %%
location.isna().sum()
# Out:
# featurecode                      0
# datecode                         0
# measurement                      0
# units                            0
# value                            0
# type_of_location_visited         0
# breakdown_of_domestic_tourism    0
# dtype: int64

# %%
transport.isna().sum()
# Out:
# featurecode                      0
# datecode                         0
# measurement                      0
# units                            0
# value                            0
# method_of_travel                 0
# breakdown_of_domestic_tourism    0
# dtype: int64

# %%
regional_tourism.shape
# Out:
# (2673, 7)

# %%
regional_tourism.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2673 entries, 0 to 2672
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   featurecode                    2673 non-null   object
#  1   datecode                       2673 non-null   object
#  2   measurement                    2673 non-null   object
#  3   units                          2673 non-null   object
#  4   value                          2673 non-null   int64
#  5   region_of_residence            2673 non-null   object
#  6   breakdown_of_domestic_tourism  2673 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 146.3+ KB

# %%
regional_tourism.describe(include='all')
# Out:
#        featurecode   datecode measurement                 units         value  \
# count         2673       2673        2673                  2673   2673.000000
# unique          33          9           1                     3           NaN
# top      S12000039  2016-2018       Count  million pounds (GBP)           NaN
# freq            81        297        2673                   891           NaN
# mean           NaN        NaN         NaN                   NaN    761.897493
# std            NaN        NaN         NaN                   NaN   3147.268188
# min            NaN        NaN         NaN                   NaN      0.000000
# 25%            NaN        NaN         NaN                   NaN     28.000000
# 50%            NaN        NaN         NaN                   NaN    106.000000
# 75%            NaN        NaN         NaN                   NaN    433.000000
# max            NaN        NaN         NaN                   NaN  44671.000000
#
# ...

# %%
regional_tourism.datecode.unique()
# Out:
# array(['2016-2018', '2015-2017', '2017-2019', '2009-2011', '2013-2015',
#        '2012-2014', '2010-2012', '2011-2013', '2014-2016'], dtype=object)

# %%
import seaborn as sns

# %%
sns.histplot(x='value',
            data=regional_tourism)
# Out:
# <AxesSubplot:xlabel='value', ylabel='Count'>

# %%
regional_tourism.head(10)
# Out:
#   featurecode   datecode measurement                 units  value  \
# 0   S12000039  2016-2018       Count  million pounds (GBP)      8
# 1   S12000039  2015-2017       Count       Thousand Nights    140
# 2   S12000039  2015-2017       Count  million pounds (GBP)      8
# 3   S12000039  2017-2019       Count       Thousand Nights     76
# 4   S12000039  2009-2011       Count       Thousand Visits     68
# 5   S12000039  2016-2018       Count       Thousand Nights     59
# 6   S12000039  2016-2018       Count  million pounds (GBP)      4
# 7   S12000039  2013-2015       Count       Thousand Visits     32
# 8   S12000039  2012-2014       Count  million pounds (GBP)      6
# 9   S12000039  2015-2017       Count       Thousand Visits     28
#
#   region_of_residence breakdown_of_domestic_tourism
# 0             England                   Expenditure
# 1           All of GB                        Nights
# 2             England                   Expenditure
# ...

# %%
(
    regional_tourism
    .loc[(regional_tourism.region_of_residence == 'Scotland') & (regional_tourism.datecode == '2009-2011'), :]
    .head(30)
)
# Out:
#     featurecode   datecode measurement                 units  value  \
# 4     S12000039  2009-2011       Count       Thousand Visits     68
# 33    S12000039  2009-2011       Count       Thousand Nights    153
# 67    S12000039  2009-2011       Count  million pounds (GBP)     14
# 103   S12000040  2009-2011       Count       Thousand Visits     98
# 109   S12000040  2009-2011       Count  million pounds (GBP)      5
# 131   S12000040  2009-2011       Count       Thousand Nights    186
# 209   S92000003  2009-2011       Count       Thousand Nights  18434
# 216   S92000003  2009-2011       Count  million pounds (GBP)    970
# 224   S92000003  2009-2011       Count       Thousand Visits   6378
# 243   S12000005  2009-2011       Count       Thousand Visits     23
# 252   S12000005  2009-2011       Count  million pounds (GBP)      2
# 260   S12000005  2009-2011       Count       Thousand Nights     39
# 364   S12000006  2009-2011       Count       Thousand Visits    341
# ...

# %%
regional_tourism.featurecode.unique()
# Out:
# array(['S12000039', 'S12000040', 'S92000003', 'S12000005', 'S12000006',
#        'S12000008', 'S12000010', 'S12000011', 'S12000013', 'S12000014',
#        'S12000017', 'S12000018', 'S12000019', 'S12000020', 'S12000021',
#        'S12000023', 'S12000026', 'S12000027', 'S12000028', 'S12000029',
#        'S12000030', 'S12000033', 'S12000034', 'S12000035', 'S12000036',
#        'S12000038', 'S12000041', 'S12000042', 'S12000045', 'S12000047',
#        'S12000048', 'S12000049', 'S12000050'], dtype=object)

# %%
test = pd.read_csv('data/download918624963420236855.csv')

# %%
test.FeatureName.unique()
# Out:
# array(['West Dunbartonshire', 'West Lothian', 'Scotland',
#        'Clackmannanshire', 'Dumfries and Galloway', 'East Ayrshire',
#        'East Lothian', 'East Renfrewshire', 'Na h-Eileanan Siar',
#        'Falkirk', 'Highland', 'Inverclyde', 'Midlothian', 'Moray',
#        'North Ayrshire', 'Orkney Islands', 'Scottish Borders',
#        'Shetland Islands', 'South Ayrshire', 'South Lanarkshire',
#        'Stirling', 'Aberdeen City', 'Aberdeenshire', 'Argyll and Bute',
#        'City of Edinburgh', 'Renfrewshire', 'Angus', 'Dundee City',
#        'East Dunbartonshire', 'Fife', 'Perth and Kinross', 'Glasgow City',
#        'North Lanarkshire'], dtype=object)

# %%
test.shape
# Out:
# (2673, 9)

# %%
test_demographics = pd.read_csv('data/download2520671026454756905.csv')

# %%
test_demographics.shape
# Out:
# (308, 15)

# %%
accomodation_occupancy
# Out:
#     featurecode  datecode measurement       units  value  \
# 0     S92000003      2012     Percent  Percentage  52.32
# 1     S92000003      2015     Percent  Percentage  49.18
# 2     S92000003      2018     Percent  Percentage  63.57
# 3     S92000003      2013     Percent  Percentage  53.35
# 4     S92000003      2018     Percent  Percentage  40.45
# ..          ...       ...         ...         ...    ...
# 706   S92000003      2015     Percent  Percentage  73.47
# 707   S92000003      2013     Percent  Percentage  35.69
# 708   S92000003      2011     Percent  Percentage  38.62
# 709   S92000003      2015     Percent  Percentage  24.37
# 710   S92000003      2017     Percent  Percentage  56.37
#
#      accommodation_type_and_occupancy weekday_weekend size_of_accommodation  \
# 0    Guest House/B&B - Room Occupancy             All                   All
# 1    Guest House/B&B - Room Occupancy             All                   All
# ...

# %%
accomodation_occupancy.describe(include='all')
# Out:
#        featurecode     datecode measurement       units       value  \
# count          711   711.000000         711         711  711.000000
# unique           1          NaN           1           1         NaN
# top      S92000003          NaN     Percent  Percentage         NaN
# freq           711          NaN         711         711         NaN
# mean           NaN  2015.000000         NaN         NaN   49.352152
# std            NaN     2.583807         NaN         NaN   13.442246
# min            NaN  2011.000000         NaN         NaN    0.000000
# 25%            NaN  2013.000000         NaN         NaN   41.345000
# 50%            NaN  2015.000000         NaN         NaN   48.860000
# 75%            NaN  2017.000000         NaN         NaN   57.265000
# max            NaN  2019.000000         NaN         NaN   87.930000
#
#        accommodation_type_and_occupancy weekday_weekend size_of_accommodation  \
# ...

# %%
(
    accomodation_occupancy
    .loc[(accomodation_occupancy.datecode < 2012) & (accomodation_occupancy.weekday_weekend == 'All') & (accomodation_occupancy.accommodation_type_and_occupancy == 'Guest House/B&B - Bed Occupancy'), :]
)
# Out:
#     featurecode  datecode measurement       units  value  \
# 99    S92000003      2011     Percent  Percentage  39.53
# 122   S92000003      2011     Percent  Percentage  40.37
# 534   S92000003      2011     Percent  Percentage  30.01
# 546   S92000003      2011     Percent  Percentage  36.48
# 563   S92000003      2011     Percent  Percentage  41.65
# 567   S92000003      2011     Percent  Percentage  49.96
# 577   S92000003      2011     Percent  Percentage  39.23
# 578   S92000003      2011     Percent  Percentage  44.33
# 599   S92000003      2011     Percent  Percentage  34.81
# 668   S92000003      2011     Percent  Percentage  49.14
#
#     accommodation_type_and_occupancy weekday_weekend size_of_accommodation  \
# 99   Guest House/B&B - Bed Occupancy             All                   All
# 122  Guest House/B&B - Bed Occupancy             All                   All
# 534  Guest House/B&B - Bed Occupancy             All          Rooms: 01-03
# ...

# %%
(
    accomodation_occupancy
    .loc[(accomodation_occupancy.datecode < 2012) & (accomodation_occupancy.weekday_weekend == 'All') & (accomodation_occupancy.accommodation_type_and_occupancy == 'Guest House/B&B - Room Occupancy'), :]
)
# Out:
#     featurecode  datecode measurement       units  value  \
# 13    S92000003      2011     Percent  Percentage  52.08
# 17    S92000003      2011     Percent  Percentage  49.63
# 50    S92000003      2011     Percent  Percentage  44.58
# 52    S92000003      2011     Percent  Percentage  44.08
# 54    S92000003      2011     Percent  Percentage  50.13
# 159   S92000003      2011     Percent  Percentage  59.68
# 290   S92000003      2011     Percent  Percentage  44.16
# 291   S92000003      2011     Percent  Percentage  36.11
# 296   S92000003      2011     Percent  Percentage  49.27
# 307   S92000003      2011     Percent  Percentage  63.98
#
#      accommodation_type_and_occupancy weekday_weekend size_of_accommodation  \
# 13   Guest House/B&B - Room Occupancy             All                   All
# 17   Guest House/B&B - Room Occupancy             All                   All
# 50   Guest House/B&B - Room Occupancy             All                   All
# ...

# %%
accomodation_occupancy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 711 entries, 0 to 710
# Data columns (total 9 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   featurecode                       711 non-null    object
#  1   datecode                          711 non-null    int64
#  2   measurement                       711 non-null    object
#  3   units                             711 non-null    object
#  4   value                             711 non-null    float64
#  5   accommodation_type_and_occupancy  711 non-null    object
#  6   weekday_weekend                   711 non-null    object
#  7   size_of_accommodation             711 non-null    object
#  8   location                          711 non-null    object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 50.1+ KB

# %%
accomodation_occupancy.accommodation_type_and_occupancy.unique()
# Out:
# array(['Guest House/B&B - Room Occupancy',
#        'Self Catering - Unit Occupancy', 'Hotels - Bed Occupancy',
#        'Hostels - Bed Occupancy', 'Guest House/B&B - Bed Occupancy',
#        'Caravan & Camping Parks - Pitch Occupancy',
#        'Hotels - Room Occupancy'], dtype=object)

# %%
accomodation_occupancy.location.unique()
# Out:
# array(['Accessible Small Towns', 'Large Urban Areas', 'Accessible Rural',
#        'All', 'Other Urban Areas', 'Remote Rural', 'Remote Small Towns'],
#       dtype=object)

# %%
activities
# Out:
#     featurecode  datecode measurement                 units  value  \
# 0     S92000003      2019       Count  million pounds (GBP)   1662
# 1     S92000003      2016       Count  million pounds (GBP)    469
# 2     S92000003      2014       Count  million pounds (GBP)    892
# 3     S92000003      2017       Count  million pounds (GBP)    354
# 4     S92000003      2015       Count  million pounds (GBP)    400
# ..          ...       ...         ...                   ...    ...
# 219   S92000003      2019       Count        Million Visits     49
# 220   S92000003      2019       Count        Million Visits      6
# 221   S92000003      2013       Count        Million Visits     29
# 222   S92000003      2018       Count        Million Visits     38
# 223   S92000003      2017       Count        Million Visits     35
#
#                                      tourism_activity  \
# 0    Shopping for items that you do not regularly buy
# ...

# %%
(
    activities
    .loc[activities.tourism_activity == 'Night out to a bar, pub and/or club', :]
)
# Out:
#     featurecode  datecode measurement                 units  value  \
# 2     S92000003      2014       Count  million pounds (GBP)    892
# 43    S92000003      2019       Count  million pounds (GBP)   1111
# 46    S92000003      2018       Count  million pounds (GBP)   1150
# 48    S92000003      2013       Count  million pounds (GBP)    840
# 50    S92000003      2017       Count  million pounds (GBP)   1298
# 54    S92000003      2016       Count  million pounds (GBP)    973
# 55    S92000003      2015       Count  million pounds (GBP)    876
# 141   S92000003      2015       Count        Million Visits     19
# 142   S92000003      2013       Count        Million Visits     18
# 146   S92000003      2018       Count        Million Visits     19
# 149   S92000003      2019       Count        Million Visits     18
# 150   S92000003      2014       Count        Million Visits     20
# 158   S92000003      2016       Count        Million Visits     20
# ...

# %%
activities.describe(include='all')
# Out:
#        featurecode     datecode measurement                 units  \
# count          224   224.000000         224                   224
# unique           1          NaN           1                     2
# top      S92000003          NaN       Count  million pounds (GBP)
# freq           224          NaN         224                   112
# mean           NaN  2016.000000         NaN                   NaN
# std            NaN     2.004479         NaN                   NaN
# min            NaN  2013.000000         NaN                   NaN
# 25%            NaN  2014.000000         NaN                   NaN
# 50%            NaN  2016.000000         NaN                   NaN
# 75%            NaN  2018.000000         NaN                   NaN
# max            NaN  2019.000000         NaN                   NaN
#
#               value                                  tourism_activity  \
# count    224.000000                                               224
# ...

# %%
demographics
# Out:
#     featurecode  datecode measurement                 units  value  \
# 0     S92000003      2013       Count        Million Visits     22
# 1     S92000003      2013       Count        Million Visits     58
# 2     S92000003      2016       Count        Million Visits     23
# 3     S92000003      2019       Count        Million Visits     56
# 4     S92000003      2015       Count        Million Visits     52
# ..          ...       ...         ...                   ...    ...
# 303   S92000003      2019       Count  million pounds (GBP)    715
# 304   S92000003      2018       Count        Million Visits     15
# 305   S92000003      2015       Count        Million Visits     15
# 306   S92000003      2013       Count        Million Visits     46
# 307   S92000003      2016       Count        Million Visits     11
#
#     breakdown_of_domestic_tourism          age marital_status gender  \
# 0                          Visits  45-54 years            All    All
# ...

# %%
demographics.describe(include='all')
# Out:
#        featurecode     datecode measurement           units        value  \
# count          308   308.000000         308             308   308.000000
# unique           1          NaN           1               2          NaN
# top      S92000003          NaN       Count  Million Visits          NaN
# freq           308          NaN         308             154          NaN
# mean           NaN  2016.000000         NaN             NaN   933.685065
# std            NaN     2.003255         NaN             NaN  1306.514196
# min            NaN  2013.000000         NaN             NaN    11.000000
# 25%            NaN  2014.000000         NaN             NaN    33.500000
# 50%            NaN  2016.000000         NaN             NaN   191.500000
# 75%            NaN  2018.000000         NaN             NaN  1346.750000
# max            NaN  2019.000000         NaN             NaN  5995.000000
#
#        breakdown_of_domestic_tourism  age marital_status gender  \
# ...

# %%
(
    demographics
    .loc[(demographics.datecode == 2013), :]
)
# Out:
#     featurecode  datecode measurement                 units  value  \
# 0     S92000003      2013       Count        Million Visits     22
# 1     S92000003      2013       Count        Million Visits     58
# 11    S92000003      2013       Count        Million Visits     19
# 20    S92000003      2013       Count        Million Visits     23
# 21    S92000003      2013       Count        Million Visits     18
# 22    S92000003      2013       Count        Million Visits     21
# 28    S92000003      2013       Count        Million Visits     75
# 43    S92000003      2013       Count  million pounds (GBP)    522
# 50    S92000003      2013       Count  million pounds (GBP)    994
# 57    S92000003      2013       Count        Million Visits     48
# 68    S92000003      2013       Count        Million Visits    124
# 76    S92000003      2013       Count        Million Visits     66
# 87    S92000003      2013       Count        Million Visits     40
# ...

# %%
location
# Out:
#     featurecode  datecode measurement                 units  value  \
# 0     S92000003      2014       Count  million pounds (GBP)    186
# 1     S92000003      2019       Count  million pounds (GBP)   1456
# 2     S92000003      2016       Count  million pounds (GBP)   4916
# 3     S92000003      2018       Count  million pounds (GBP)   5474
# 4     S92000003      2013       Count  million pounds (GBP)    217
# ..          ...       ...         ...                   ...    ...
# 107   S92000003      2019       Count        Million Visits      1
# 108   S92000003      2015       Count        Million Visits      2
# 109   S92000003      2018       Count        Million Visits    138
# 110   S92000003      2013       Count        Million Visits      3
# 111   S92000003      2017       Count        Million Visits    151
#
#     type_of_location_visited breakdown_of_domestic_tourism
# 0            Seaside - beach                   Expenditure
# ...

# %%
location.describe(include='all')
# Out:
#        featurecode     datecode measurement                 units  \
# count          112   112.000000         112                   112
# unique           1          NaN           1                     2
# top      S92000003          NaN       Count  million pounds (GBP)
# freq           112          NaN         112                    56
# mean           NaN  2016.000000         NaN                   NaN
# std            NaN     2.008989         NaN                   NaN
# min            NaN  2013.000000         NaN                   NaN
# 25%            NaN  2014.000000         NaN                   NaN
# 50%            NaN  2016.000000         NaN                   NaN
# 75%            NaN  2018.000000         NaN                   NaN
# max            NaN  2019.000000         NaN                   NaN
#
#               value type_of_location_visited breakdown_of_domestic_tourism
# count    112.000000                      112                           112
# ...

# %%
transport
# Out:
#     featurecode  datecode measurement                 units  value  \
# 0     S92000003      2018       Count  million pounds (GBP)  251.8
# 1     S92000003      2018       Count  million pounds (GBP)    1.8
# 2     S92000003      2014       Count  million pounds (GBP)   97.8
# 3     S92000003      2017       Count  million pounds (GBP)  168.8
# 4     S92000003      2018       Count  million pounds (GBP)  193.1
# ..          ...       ...         ...                   ...    ...
# 231   S92000003      2018       Count        Million Visits   12.2
# 232   S92000003      2018       Count        Million Visits   84.2
# 233   S92000003      2013       Count        Million Visits   79.7
# 234   S92000003      2016       Count        Million Visits    0.2
# 235   S92000003      2015       Count        Million Visits    0.2
#
#              method_of_travel breakdown_of_domestic_tourism
# 0                      Walked                   Expenditure
# ...

# %%
transport.describe(include='all')
# Out:
#        featurecode     datecode measurement                 units  \
# count          236   236.000000         236                   236
# unique           1          NaN           1                     2
# top      S92000003          NaN       Count  million pounds (GBP)
# freq           236          NaN         236                   118
# mean           NaN  2015.898305         NaN                   NaN
# std            NaN     2.010144         NaN                   NaN
# min            NaN  2013.000000         NaN                   NaN
# 25%            NaN  2014.000000         NaN                   NaN
# 50%            NaN  2016.000000         NaN                   NaN
# 75%            NaN  2018.000000         NaN                   NaN
# max            NaN  2019.000000         NaN                   NaN
#
#               value method_of_travel breakdown_of_domestic_tourism
# count    236.000000              236                           236
# ...

# %%
(
    transport
    .loc[(transport.datecode < 2014) & (transport.method_of_travel == 'All'), :]
)
# Out:
#     featurecode  datecode measurement                 units   value  \
# 115   S92000003      2013       Count  million pounds (GBP)  4646.7
# 133   S92000003      2013       Count        Million Visits   123.9
#
#     method_of_travel breakdown_of_domestic_tourism
# 115              All                   Expenditure
# 133              All                        Visits

# %%
transport.method_of_travel.unique()
# Out:
# array(['Walked', 'Caravan/Campervan', 'Plane', 'Boat/Ship/Ferry',
#        'Bus or Coach - Regular', 'Train', 'Taxi', 'Bicycle',
#        'Bus or Coach - Minibus', 'Lorry/Truck/Van',
#        'Bus or Coach - Organised Tour', 'Other', 'Tube', 'All',
#        'Car - hired', 'Car - own/friends/family', 'Tram', 'Motor cycle'],
#       dtype=object)
